# %% [markdown]
# ## Ejercicio 1
#
# Hallar, en el intervalo $-10 \leq x \leq 10$, el mínimo de la función
#
# $$
# y = -1 + (x - 2)^2
# $$

# %%
import numpy as np
from scipy.optimize import fmin
import matplotlib.pyplot as plt

def y(x):

    return -1 + (x-2)**2

x0 = 1

fmin(y, x0, disp=True, full_output=True)
# Out:
# Optimization terminated successfully.
#          Current function value: -1.000000
#          Iterations: 17
#          Function evaluations: 34
# (array([2.]), -1.0, 17, 34, 0)

# %% [markdown]
# # Ejercicio 2
#
# **Dada la función:**
#
# $$
# y = -\frac{\text{sen } x}{x} - 5
# $$
#
# **Hallar todos los mínimos contenidos en el intervalo**
# $-15 \leq x \leq 15$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fmin

def f(x):
    
    return np.where(x != 0, -np.sin(x)/x -5, -6)

xp = np.linspace(-15,15,100)
plt.plot(xp, f(xp))
plt.xlabel('x')
plt.ylabel('y')

xtry = np.arange(-15,15, 1)

mins = [np.round(fmin(f, x0=xtry[0], disp=False)[0], 2)]

for i in range(1,len(xtry)):

    min = np.round(fmin(f, x0=xtry[i], disp=False)[0], 2)

    if min not in mins:

        mins.append(min)

mins = np.array(mins)
fmins = f(mins)
print('Los mínimos son:')
for i in range(len(mins)):
    
    print(f'x = {mins[i]}, y = {fmins[i]:.2f}')
# Out:
# Los mínimos son:
# x = -14.07, y = -5.07
# x = -7.73, y = -5.13
# x = 0.0, y = -6.00
# x = 7.73, y = -5.13
# x = 14.07, y = -5.07
# C:\Users\alrog\AppData\Local\Temp\ipykernel_25008\800407723.py:7: RuntimeWarning: invalid value encountered in divide
#   return np.where(x != 0, -np.sin(x)/x -5, -6)

# %%
'''
def funci(x):
    if np.abs(x.any()) < 1e-4:
        sol = -6.
    else:
        sol = -np.sin(x)/x-5
    return sol

minimos_lista = []
x = np.linspace(-15, 15, 100)
for elem in x:
    minimo = np.round(fmin(funci, x0=elem, disp=False)[0], 3)
    if minimo not in minimos_lista:
        minimos_lista.append(minimo)
        print(f'El mínimo número %.0f está en (x, y) = (%.3f, %.3f)' %(len(minimos_lista), minimo, funci(minimo)))
    else:
        continue

plt.figure()
plt.plot(x, funci(x), '-')
plt.title(r'$y=-\frac{\sin x}{x}-5$')
'''
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\alrog\AppData\Local\Temp\ipykernel_25008\696518482.py:1: SyntaxWarning: invalid escape sequence '\s'
#   '''
# "\ndef funci(x):\n    if np.abs(x.any()) < 1e-4:\n        sol = -6.\n    else:\n        sol = -np.sin(x)/x-5\n    return sol\n\nminimos_lista = []\nx = np.linspace(-15, 15, 100)\nfor elem in x:\n    minimo = np.round(fmin(funci, x0=elem, disp=False)[0], 3)\n    if minimo not in minimos_lista:\n        minimos_lista.append(minimo)\n        print(f'El mínimo número %.0f está en (x, y) = (%.3f, %.3f)' %(len(minimos_lista), minimo, funci(minimo)))\n    else:\n        continue\n\nplt.figure()\nplt.plot(x, funci(x), '-')\nplt.title(r'$y=-\x0crac{\\sin x}{x}-5$')\n"

# %% [markdown]
# ## Ejercicio 3
#
# Dada la función:
#
# $$
# y = -\frac{\sin x}{x} - 5
# $$
#
# Hallar el **mínimo global** en el intervalo $-15 \leq x \leq 15$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fmin

def f(x):
    
    return np.where(x != 0, -np.sin(x)/x -5, -6)
xp = np.linspace(-15,15,100)
plt.plot(xp, f(xp))
plt.xlabel('x')
plt.ylabel('y')

xtry = np.arange(-15,15, 1)

mins = [np.round(fmin(f, x0=xtry[0], disp=False)[0], 2)]

for i in range(1,len(xtry)):

    min = np.round(fmin(f, x0=xtry[i], disp=False)[0], 2)

    if min not in mins:

        mins.append(min)

mins = np.array(mins)
fmins = f(mins)

print(f'El mínimo global es x = {mins[np.argmin(fmins)]}, y = {np.min(fmins)}')
# Out:
# El mínimo global es x = 0.0, y = -6.0
# C:\Users\alrog\AppData\Local\Temp\ipykernel_25008\925631027.py:7: RuntimeWarning: invalid value encountered in divide
#   return np.where(x != 0, -np.sin(x)/x -5, -6)

# %% [markdown]
# ## Ejercicio 4
#
# Dada la función:
#
# $$
# y = -\frac{\sin x}{x} - 5
# $$
#
# Hallar **todos los máximos y mínimos** contenidos en el intervalo $-15 \leq x \leq 15$.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fmin

def f(x):
    return np.where(x != 0, -np.sin(x)/x -5, -6)
def g(x):
    return -f(x)


xp = np.linspace(-15,15,100)
plt.plot(xp, f(xp))
plt.xlabel('x')
plt.ylabel('y')

xtry = np.arange(-13,13, 1)

mins = [np.round(fmin(f, x0=xtry[0], disp=False)[0], 2)]
maxs = [np.round(fmin(g, x0=xtry[0], disp=False)[0], 2)]

for i in range(1,len(xtry)):

    min = np.round(fmin(f, x0=xtry[i], disp=False)[0], 2)
    max = np.round(fmin(g, x0=xtry[i], disp=False)[0], 2)
    if min not in mins:
        mins.append(min)
    if max not in maxs:
        maxs.append(max)

mins = np.array(mins)
maxs = np.array(maxs)
fmins = f(mins)
fmaxs = f(maxs)

print('Mínimos:')
for i in range(len(mins)):
    print(f'x = {mins[i]}, y = {fmins[i]:.2f}')

print('Máximos:')
for i in range(len(maxs)):
    print(f'x = {maxs[i]}, y = {fmaxs[i]:.2f}')
# Out:
# Mínimos:
# x = -14.07, y = -5.07
# x = -7.73, y = -5.13
# x = 0.0, y = -6.00
# x = 7.73, y = -5.13
# x = 14.07, y = -5.07
# Máximos:
# x = -10.9, y = -4.91
# x = -4.49, y = -4.78
# x = 4.49, y = -4.78
# x = 10.9, y = -4.91
# C:\Users\alrog\AppData\Local\Temp\ipykernel_25008\1661937595.py:6: RuntimeWarning: invalid value encountered in divide
#   return np.where(x != 0, -np.sin(x)/x -5, -6)

# %% [markdown]
# ## Ejercicio 5
#
# Calcular el **mínimo** de la función:
#
# $$
# f(x, y) = x^2 + y^4 + x + y
# $$
#
# para el dominio:
# $$
# -5 \leq x \leq 5 \\
# -5 \leq y \leq 5

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

def f(x):
    x, y = x
    return x**2 + y**4 + x + y

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')
ax.view_init(elev=20, azim=-20)

x = y = np.linspace(-5,5,10)
X, Y = np.meshgrid(x,y)
ax.plot_wireframe(X,Y, f([X,Y]))

xmin = ymin = -5
xmax = ymax = 5

minimo = minimize(f, x0=(0,0), bounds=([xmin,xmax],[ymin,ymax]))
x0, y0 = minimo.x
fmin = minimo.fun
print(f'El mínimo es x = {x0:.2f}, y = {y0:.2f}, f(x,y) = {fmin:.2f}')

ax.plot(x0,y0, f([x0,y0]), 'ro', zorder = 1000)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

fig.tight_layout()
plt.show()
# Out:
# El mínimo es x = -0.50, y = -0.63, f(x,y) = -0.72

# %% [markdown]
# ## Ejercicio 6
#
# Calcular el **mínimo** de la función:
#
# $$
# f(x, y) = x^2 + y^2 + 8
# $$
#
# para el dominio:
# $$
# -10 \leq x \leq 10 \\
# -10 \leq y \leq 10

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

def f(x):
    x, y = x
    return x**2 + y**2 + 8

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = y = np.linspace(-10,10,100)
x, y = np.meshgrid(x,y)
ax.plot_wireframe(x,y, f([x,y]))

xmin = ymin = -10
xmax = ymax = 10

minimo = minimize(f, x0=(0,0), bounds=([xmin,xmax],[ymin,ymax]))
x0, y0 = minimo.x
fmin = minimo.fun
print(f'El mínimo es x = {x0:.2f}, y = {y0:.2f}, f(x,y) = {fmin:.2f}')

ax.plot(x0,y0, f([x0,y0]), 'ro', zorder = 10, label = 'minimo')

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.view_init(elev=20, azim=-75)

fig.tight_layout()
plt.legend()
plt.show()
# Out:
# El mínimo es x = 0.00, y = 0.00, f(x,y) = 8.00

# %% [markdown]
# ## Ejercicio 7
#
# Calcular el **mínimo** de la función:
#
# $$
# f(x, y) = x e^{-(x^2 + y^2)}
# $$
#
# para el dominio:
# $$
# -1 \leq x \leq 1 \\
# -1 \leq y \leq 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize

def f(x):
    x, y = x
    return x*np.exp(-x**2-y**2)

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = y = np.linspace(-1,1,100)
x, y = np.meshgrid(x,y)
ax.plot_wireframe(x,y, f([x,y]))


xmin = ymin = -1
xmax = ymax = 1

minimo = minimize(f, x0=(0,0), bounds=([xmin,xmax],[ymin,ymax]))
x0, y0 = minimo.x
fmin = minimo.fun
print(f'El mínimo es x = {x0:.2f}, y = {y0:.2f}, f(x,y) = {fmin:.2f}')

ax.plot(x0,y0, f([x0,y0]), 'ro', zorder = 10)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

fig.tight_layout()

plt.show()
# Out:
# El mínimo es x = -0.71, y = -0.00, f(x,y) = -0.43
